# %%
# Importing required libraries
#!pip install python-google-places
#import googleplaces
from googleplaces import GooglePlaces, types, lang
import requests
import json

# This is the way to make api requests 
# using python requests library 
  
# send_url = 'http://freegeoip.net/json' 
# r = requests.get(send_url) 
# j = json.loads(r.text) 
# print(j) 
# lat = j['latitude'] 
# lon = j['longitude'] 
  
# Generate an API key by going to this location 
# https://cloud.google.com /maps-platform/places/?apis = 
# places in the google developers 
  
# Use your own API key for making api request calls 
API_KEY = '' << API KEY HERE

# Initialising the GooglePlaces constructor 
google_places = GooglePlaces(API_KEY) 

# call the function nearby search with 
# the parameters as longitude, latitude, 
# radius and type of place which needs to be searched of  
# type can be HOSPITAL, CAFE, BAR, CASINO, etc 
query_result = google_places.nearby_search( 
    # lat_lng ={'lat': 46.1667, 'lng': -1.15}, 
        lat_lng ={'lat': 28.4720443, 'lng': 77.1329417}, 
    radius = 5000, 
    # types =[types.TYPE_HOSPITAL] or 
    # [types.TYPE_CAFE] or [type.TYPE_BAR] 
    # or [type.TYPE_CASINO]) 
    types =[types.TYPE_HOSPITAL])
    #key_word = 'Shelter Home'

print(query_result)

# If any attributions related  
# with search results print them 
if query_result.has_attributions: 
    print (query_result.html_attributions)

# Iterate over the search results 
for place in query_result.places: 
    # print(type(place)) 
    # place.get_details() 
    print (place.name) 
    print("Latitude", place.geo_location['lat']) 
    print("Longitude", place.geo_location['lng']) 
    print()
# Out:
# <GooglePlacesSearchResult with 20 result(s)>
# Tulasi Home
# Latitude 28.4487914
# Longitude 77.13835949999999
#
# St Stephen’s Hospital Health Care Facility
# Latitude 28.4854603
# Longitude 77.10490059999999
#
# SafeMedTrip.com
# Latitude 28.4829869
# Longitude 77.09597309999999
#
# Neelkanth Hospitals - Best IVF Hospital in Gurgaon, Delhi NCR
# Latitude 28.4834867
# Longitude 77.1076949
#
# My Doctors Directory - A complete Medical Portal for Gurgaon
# Latitude 28.471464
# Longitude 77.09862
#
# Firstcare Medicare
# Latitude 28.480957
# Longitude 77.102295
#
# Medma Health Care
# Latitude 28.476042
# Longitude 77.12897099999999
#
# Dr. Anwar Medical Centre
# Latitude 28.4753197
# Longitude 77.1395072
#
# Delhi Government Dispensary
# Latitude 28.4633209
# Longitude 77.1519254
#
# Skyn Stories l Dr. Meenu Sethi
# Latitude 28.4721275
# Longitude 77.1018211
#
# Green Park
# Latitude 28.478122
# Longitude 77.1646774
#
# Fortis Healthworld
# Latitude 28.4591444
# Longitude 77.1038532
#
# Batra Associates
# Latitude 28.4663599
# Longitude 77.1003219
#
# Saaol Science and Art of Living
# Latitude 28.4829077
# Longitude 77.1640233
#
# Fortis Healthworld
# Latitude 28.466054
# Longitude 77.099161
#
# Dr Guri Skin centre
# Latitude 28.4931795
# Longitude 77.1081435
#
# Kamanya Wellness Clinic
# Latitude 28.4928411
# Longitude 77.1063812
#
# vidal hospital
# Latitude 28.4699495
# Longitude 77.09632259999999
#
# Qi Spine Clinic
# Latitude 28.4719121
# Longitude 77.0951669
#
# Kerala Ayurvedic Clinic
# Latitude 28.48101
# Longitude 77.0855419
