# %%
import requests

headers = {
    'Referer': 'https://mobile.twitter.com/unitedbyblue/status/1288983803202084865/photo/1',
    'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36',
}

params = (
    ('format', 'jpg'),
    ('name', 'large'),
)

response = requests.get('https://pbs.twimg.com/media/EeM3N6dXgAIulR0', headers=headers, params=params)

# %%
import requests

media_id = 'EeNj7lWWsAkaklv'
url = f'https://pbs.twimg.com/media/{media_id}?format=jpg&name=large'
url = 'https://api.twitter.com/2/timeline/conversation/1288983803202084865.json?include_profile_interstitial_type=1&include_blocking=1&include_blocked_by=1&include_followed_by=1&include_want_retweets=1&include_mute_edge=1&include_can_dm=1&include_can_media_tag=1&skip_status=1&cards_platform=Web-12&include_cards=1&include_ext_alt_text=true&include_quote_count=true&include_reply_count=1&tweet_mode=extended&include_entities=true&include_user_entities=true&include_ext_media_color=true&include_ext_media_availability=true&send_error_codes=true&simple_quoted_tweet=true&count=20&include_ext_has_birdwatch_notes=false&ext=mediaStats%2ChighlightedLabel'

response = requests.get(url)

# %%
import requests

headers = {
    'authority': 'api.twitter.com',
    'authorization': 'Bearer AAAAAAAAAAAAAAAAAAAAANRILgAAAAAAnNwIzUejRCOuH5E6I8xnZz4puTs%3D1Zv7ttfk8LF81IUq16cHjhLTvJu4FA33AGWWjCpTnA',
    'x-twitter-client-language': 'en',
    'x-csrf-token': 'a9be5eeec125951bdc7a0029055b2d1c',
    'x-guest-token': '1309851214952054784',
    'x-twitter-active-user': 'yes',
    'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36',
    'accept': '*/*',
    'origin': 'https://twitter.com',
    'sec-fetch-site': 'same-site',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://twitter.com/unitedbyblue/status/1288983803202084865',
    'accept-language': 'en-US,en;q=0.9',
    'cookie': 'personalization_id="v1_FFwj0E1rM12wqaoP1O+zCQ=="; guest_id=v1%3A160112783972147750; gt=1309851214952054784; ct0=a9be5eeec125951bdc7a0029055b2d1c; _twitter_sess=BAh7CSIKZmxhc2hJQzonQWN0aW9uQ29udHJvbGxlcjo6Rmxhc2g6OkZsYXNo%250ASGFzaHsABjoKQHVzZWR7ADoPY3JlYXRlZF9hdGwrCFAHqMp0AToMY3NyZl9p%250AZCIlNWU4MTFkMjM5ZDNjMzA3MzZiYTk3NTlmZjI2YWZiZjU6B2lkIiVkYjJm%250AMDg0NjZlMDNkMDJkYjUxMWJhNTdmMzhhNjA3ZA%253D%253D--4eae7c68ffe37aac27d0a62cb30245a90f98c54b; _ga=GA1.2.1725768101.1601127846; _gid=GA1.2.157018568.1601127846',
}

params = (
    ('include_profile_interstitial_type', '1'),
    ('include_blocking', '1'),
    ('include_blocked_by', '1'),
    ('include_followed_by', '1'),
    ('include_want_retweets', '1'),
    ('include_mute_edge', '1'),
    ('include_can_dm', '1'),
    ('include_can_media_tag', '1'),
    ('skip_status', '1'),
    ('cards_platform', 'Web-12'),
    ('include_cards', '1'),
    ('include_ext_alt_text', 'true'),
    ('include_quote_count', 'true'),
    ('include_reply_count', '1'),
    ('tweet_mode', 'extended'),
    ('include_entities', 'true'),
    ('include_user_entities', 'true'),
    ('include_ext_media_color', 'true'),
    ('include_ext_media_availability', 'true'),
    ('send_error_codes', 'true'),
    ('simple_quoted_tweet', 'true'),
    ('count', '20'),
    ('include_ext_has_birdwatch_notes', 'false'),
    ('ext', 'mediaStats,highlightedLabel'),
)

response = requests.get('https://api.twitter.com/2/timeline/conversation/1288983803202084865.json', headers=headers, params=params)

# %%
import requests

cookies = {
    'personalization_id': 'v1_bERC0ifB5xhV5J8mZyweIA==',
    'guest_id': 'v1%3A160112988876258003',
    'gt': '1309859807470346240',
    'ct0': '6ff32af16eff00ab9f98cf3810d01a19',
}

headers = {
    'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:80.0) Gecko/20100101 Firefox/80.0',
    'Accept': '*/*',
    'Accept-Language': 'en-US,en;q=0.5',
    'authorization': 'Bearer AAAAAAAAAAAAAAAAAAAAANRILgAAAAAAnNwIzUejRCOuH5E6I8xnZz4puTs%3D1Zv7ttfk8LF81IUq16cHjhLTvJu4FA33AGWWjCpTnA',
    'x-guest-token': '1309859807470346240',
    'x-twitter-client-language': 'en',
    'x-twitter-active-user': 'yes',
    'x-csrf-token': '6ff32af16eff00ab9f98cf3810d01a19',
    'Origin': 'https://twitter.com',
    'DNT': '1',
    'Connection': 'keep-alive',
    'Referer': 'https://twitter.com/',
    'TE': 'Trailers',
}

params = (
    ('include_profile_interstitial_type', '1'),
    ('include_blocking', '1'),
    ('include_blocked_by', '1'),
    ('include_followed_by', '1'),
    ('include_want_retweets', '1'),
    ('include_mute_edge', '1'),
    ('include_can_dm', '1'),
    ('include_can_media_tag', '1'),
    ('skip_status', '1'),
    ('cards_platform', 'Web-12'),
    ('include_cards', '1'),
    ('include_ext_alt_text', 'true'),
    ('include_quote_count', 'true'),
    ('include_reply_count', '1'),
    ('tweet_mode', 'extended'),
    ('include_entities', 'true'),
    ('include_user_entities', 'true'),
    ('include_ext_media_color', 'true'),
    ('include_ext_media_availability', 'true'),
    ('send_error_codes', 'true'),
    ('simple_quoted_tweet', 'true'),
    ('count', '20'),
    ('include_ext_has_birdwatch_notes', 'false'),
    ('ext', 'mediaStats,highlightedLabel'),
)

response = requests.get('https://api.twitter.com/2/timeline/conversation/1288983803202084865.json', headers=headers, params=params, cookies=cookies)

# %%
import requests

headers = {
    'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:80.0) Gecko/20100101 Firefox/80.0',
    'Accept': 'image/webp,*/*',
    'Accept-Language': 'en-US,en;q=0.5',
    'DNT': '1',
    'Connection': 'keep-alive',
    'Referer': 'https://twitter.com/',
}

params = (
    ('format', 'jpg'),
    ('name', 'large'),
)

response = requests.get('https://pbs.twimg.com/media/EeNj7lWWsAkaklv', headers=headers, params=params)

#NB. Original query string below. It seems impossible to parse and
#reproduce query strings 100% accurately so the one below is given
#in case the reproduced version is not "correct".
# response = requests.get('https://pbs.twimg.com/media/EeNj7lWWsAkaklv?format=jpg&name=large', headers=headers)

# %%
response
# Out:
# <Response [200]>

# %%
response.content
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00H\x00H\x00\x00\xff\xdb\x00C\x00\x04\x04\x04\x04\x04\x04\x07\x04\x04\x07\n\x07\x07\x07\n\r\n\n\n\n\r\x10\r\r\r\r\r\x10\x14\x10\x10\x10\x10\x10\x10\x14\x14\x14\x14\x14\x14\x14\x14\x18\x18\x18\x18\x18\x18\x1c\x1c\x1c\x1c\x1c\x1f\x1f\x1f\x1f\x1f\x1f\x1f\x1f\x1f\x1f\xff\xdb\x00C\x01\x05\x05\x05\x08\x07\x08\x0e\x07\x07\x0e \x16\x12\x16                                                  \xff\xc2\x00\x11\x08\x08\x00\x05T\x03\x01"%\'\xe1\xd83\x94\xa2*j\xa2\xf2r\x0f\'"\xa4\xe4T\x9e\xa2\xa4\xe4\x1eNEM$\x1eN\xb0St\x82\x9b\x90SDT\xd1\x054EM\x10Sb/$EM\x11b1\x154E\xa6\x88<\x91\x15$EI\x0c\xa4\x88\xbb\xb9\x15$E\xddS\'x\x8aw"\xa4\x86N\xf5\x15%\
# ...

# %%
with open('/tmp/z.jpg', 'wb') as jpeg_file:
    jpeg_file.write(response.content)
